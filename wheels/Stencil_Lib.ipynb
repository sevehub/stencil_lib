# %% [markdown]
# ## Stencil Lib for JupyterLitem

# %%
# %pip install https://sevehub.github.io/stencil_lib/wheels/stencil_lib-0.1.0-py3-none-any.whl

# %%
from stencil_lib import  stencil_lib

# %%
s = stencil_lib.Stencil(width_cm=8.7, height_cm=5.2, dpi=300)
s.add_frame()
s.add_curve("ellipse", a_cm=3.8, b_cm=2.2, stroke=(20, 20, 20, 255))
s.save("out.png")
